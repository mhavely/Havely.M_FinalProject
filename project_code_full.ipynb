# %%
# Installing the package to open my tif file

# %%
pip install rasterio
# Out:
# Collecting rasterio
#   Using cached rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
# Collecting affine (from rasterio)
#   Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from rasterio) (22.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.10/site-packages (from rasterio) (8.1.3)
# Collecting cligj>=0.5 (from rasterio)
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rasterio) (1.26.0)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Using cached snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins (from rasterio)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio) (67.6.1)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/conda/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Installing collected packages: snuggs, cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.3.9 snuggs-1.4.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# Installing the package to convert my utm coordinates to lat/lon

# %%
pip install utm
# Out:
# Collecting utm
#   Using cached utm-0.7.0-py3-none-any.whl
# Installing collected packages: utm
# Successfully installed utm-0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing packages
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import rasterio
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import utm

# %%
# Opening Bathymetry File
filepath_asc = 'bathy_asc_lake_crescent.asc'

# Converted to a Numpy Array
dn_asc = np.genfromtxt(filepath_asc, skip_header = 6, dtype = float, delimiter = ' ')

# %%
# Seeing what the Numpy array looks like without recreating it
print(len(dn_asc))
display(dn_asc)
# Out:
# 1758
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]])

# %%
# Opening acoustic backscatter file
## Using https://stackoverflow.com/questions/44534009/plotting-with-rasterio
filepath_tif = 'back_tif_lake_crescent.tif'
img = rasterio.open(filepath_tif)
# Out:
# /opt/conda/lib/python3.10/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
# Setting up NumPy Array
x = np.arange(431687, 444833, 3)
y = np.arange(5321907, 5327181, 3)
## Checking to make sure it's a Numpy array and the dimensions are right
print(x)
print('x:', len(x))
print('y:', len(y))
# Out:
# [431687 431690 431693 ... 444824 444827 444830]
# x: 4382
# y: 1758

# %%
# Converting Numpy Array to xr
data_xr = xr.DataArray(data = dn_asc, dims = ['y', 'x'], coords = {'x':x, 'y':y})
# Taking out -9999 variables (invalid data)
data_xr = data_xr.where(data_xr != -9999)
display(data_xr)
# Out:
# <xarray.DataArray (y: 1758, x: 4382)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#   * x        (x) int64 431687 431690 431693 431696 ... 444824 444827 444830
#   * y        (y) int64 5321907 5321910 5321913 ... 5327172 5327175 5327178

# %%
# Defined bathymetry Graph
## Kathy's Feedback - bathymetry for contour and color for acoustic backscatter
fig, ax = plt.subplots(figsize = (10,6))
ax = plt.gca()

cntr = plt.contourf(x, y, np.flip(data_xr, axis = 0), cmap = 'viridis') 
colorbar = plt.colorbar()
## Adding labels
colorbar.set_label('Depth (m)', fontsize = 14)
plt.xlabel('Longtiude (UTM)', fontsize = 14)
plt.ylabel('Latitude (UTM)', fontsize = 14)
plt.title('Bathymetric Data of Lake Crescent', fontsize = 16)

## Dowloading the graph
### Using https://futurestud.io/tutorials/matplotlib-save-plots-as-file
plt.savefig('bathymetry_data_undefined')

# %%
# Defined bathymetry Graph
## Kathy's Feedback - bathymetry for contour and color for acoustic backscatter
fig, ax = plt.subplots(figsize = (10,6))
ax = plt.gca()

cntr = plt.contourf(x, y, np.flip(data_xr, axis = 0), cmap = 'viridis', levels = 5) 
colorbar = plt.colorbar()
## Adding labels
colorbar.set_label('Depth (m)', fontsize = 14)
plt.xlabel('Longtiude (UTM)', fontsize = 14)
plt.ylabel('Latitude (UTM)', fontsize = 14)
plt.title('Bathymetric Data of Lake Crescent', fontsize = 16)
## Adding contour lines for definition
cntr_lines = plt.contour(x, y, np.flip(data_xr, axis = 0), colors = 'black', levels = 5, linewith = 1)

## Dowloading the graph
plt.savefig('bathymetry_data')
# Out:
# /tmp/ipykernel_65/3598633502.py:14: UserWarning: The following kwargs were not used by contour: 'linewith'
#   cntr_lines = plt.contour(x, y, np.flip(data_xr, axis = 0), colors = 'black', levels = 5, linewith = 1)

# %%
# Making the Lake Crescent 
fig = plt.figure(figsize = (10,6))
ax = plt.axes(projection = ccrs.PlateCarree())
# Adding in features
## Using https://foundations.projectpythia.org/core/cartopy/cartopy.html for gridlines code
gl = ax.gridlines(draw_labels = True, linewidth = 2, color = 'gray', alpha = 0.4, linestyle = '--')
gl.xlabels_top = False
gl.ylabels_right = False
ax.coastlines(resolution = '10m', color = 'k')
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.STATES)
## Using https://www.naturalearthdata.com/downloads/10m-natural-earth-1/10m-natural-earth-1-with-shaded-relief-and-water/
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'rivers_north_america', '10m'))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'lakes_north_america', '10m'))
# Zooming in on Lake Crescent via cartopy
ax.set_extent([-125, -123, 47, 49], crs = ccrs.PlateCarree())

## Downloading the Graph
plt.savefig('failed_lake_graph')
# Out:
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
# Acoustic Backscatter Plot
fig,ax = plt.subplots(figsize = (10,6))
ax = plt.gca()

plt.imshow(img.read(1), cmap = 'viridis')
colorbar = plt.colorbar()
## Adding in features
colorbar.set_label('Acoustic Backscatter (m)', fontsize = 14)
plt.xlabel('Horizontal Pixels', fontsize = 14)
plt.ylabel('Vertical Pixels', fontsize = 14)
plt.title('Acoustic Backscatter Data of Lake Crescent', fontsize = 16)

## Downloading the Graph
plt.savefig('backscatter_data')

# %%
# Combining Graphs
fig, ax = plt.subplots(figsize = (10,6))
ax = plt.gca()

## Acoustic backscatter data
extent = x.min(), x.max(), y.min(), y.max()
plt.imshow(img.read(1), cmap = 'viridis', extent = extent)
colorbar = plt.colorbar()
## Adding labels
colorbar.set_label('Acoustic Backscatter (units)', fontsize = 14)
plt.xlabel('Horizontal Pixels', fontsize = 14)
plt.ylabel('Vertical Pixels', fontsize = 14)
plt.title('Acoustic Backscatter Data of Lake Crescent', fontsize = 16)
## Bathymetry data
cntr = ax.contourf(x, y, data_xr, cmap = 'viridis', levels = 5, linewith = 1) 
cntr_lines = ax.contour(x, y, data_xr, colors = 'black', levels = 5, linewith = 1)
plt.clabel(cntr_lines)

## Downloading the graph
plt.savefig('failed_graph_2.png')
# Out:
# /tmp/ipykernel_102/1473498842.py:12: UserWarning: The following kwargs were not used by contour: 'linewith'
#   cntr = ax.contourf(x, y, data_xr, cmap = 'viridis', levels = 5, linewith = 1)
# /tmp/ipykernel_102/1473498842.py:13: UserWarning: The following kwargs were not used by contour: 'linewith'
#   cntr_lines = ax.contour(x, y, data_xr, colors = 'black', levels = 5, linewith = 1)

# %%
# Combining Graphs
## Using https://stackoverflow.com/questions/72908430/how-to-invert-y-axis-in-subplot-python
axes,(p1, p2) = plt.subplots(1, 2, figsize = (10,6))
ax = plt.gca()

## Importing acoustic backscatter data
extent = x.min(), x.max(), y.min(), y.max()
p1.imshow(img.read(1), cmap = 'viridis', extent = extent)
## Adding labels
plt.xlabel('Horizontal Pixels', fontsize = 14)
plt.ylabel('Vertical Pixels', fontsize = 14)
plt.title('Acoustic Backscatter Data of Lake Crescent', fontsize = 16)
## Bathymetry data
cntr = p2.contourf(x, y, np.flip(data_xr, axis = 0), cmap = 'viridis', levels = 5, linewith = 1) 
cntr_lines = p2.contour(x, y, np.flip(data_xr, axis = 0), colors = 'black', levels = 5, linewith = 1)
p2.clabel(cntr_lines)

## Downloading the graph
plt.savefig('failed_graph_1.png')
# Out:
# /tmp/ipykernel_102/1339131345.py:11: UserWarning: The following kwargs were not used by contour: 'linewith'
#   cntr = p2.contourf(x, y, np.flip(data_xr, axis = 0), cmap = 'viridis', levels = 5, linewith = 1)
# /tmp/ipykernel_102/1339131345.py:12: UserWarning: The following kwargs were not used by contour: 'linewith'
#   cntr_lines = p2.contour(x, y, np.flip(data_xr, axis = 0), colors = 'black', levels = 5, linewith = 1)

# %%
# Combining Graphs
fig, ax = plt.subplots(figsize = (10,6))
ax = plt.gca()

## Acoustic backscatter data
extent = x.min(), x.max(), y.min(), y.max()
plt.imshow(img.read(1), cmap = 'viridis', extent = extent)
colorbar = plt.colorbar()
## Adding features
colorbar.set_label('Acoustic Backscatter (m)', fontsize = 14)
plt.xlabel('Longitude (UTM)', fontsize = 14)
plt.ylabel('Latitude (UTM)', fontsize = 14)
plt.title('Bathymetry and Acoustic Backscatter Data of Lake Crescent', fontsize = 16)
## Bathymetry data
cntr_lines = plt.contour(x, y, np.flip(data_xr, axis = 0), colors = 'white', levels = 3, linewith = 1)
plt.clabel(cntr_lines)

plt.savefig('back_and_bath_graph')
# Out:
# /tmp/ipykernel_102/4078074090.py:12: UserWarning: The following kwargs were not used by contour: 'linewith'
#   cntr_lines = plt.contour(x, y, np.flip(data_xr, axis = 0), colors = 'white', levels = 3, linewith = 1)
